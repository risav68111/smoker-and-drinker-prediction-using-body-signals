# %% [markdown]
# ##  Name: Rishav Kumar
# ##  Roll no: 2301560042
#
# ## Github Link: [Link](https://github.com/risav68111/mca_sem_1_project)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('datasets\\smoking_drinking_dataset_Ver01.csv')
df.head(5)
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %% [markdown]
# Count the total number of records in the dataset

# %%
len(df)
# Out:
# 991346

# %% [markdown]
# Calculate the average age, height, weight and waistline measurement of the individuals in the dataset.

# %%
av_age= int(df.age.mean())
av_height= int(df.height.mean())
av_weight= int(df.weight.mean())

print(f'average age= {av_age}, height= {av_height}, weight= {av_weight}')
# Out:
# average age= 47, height= 162, weight= 63

# %% [markdown]
# Find the minimum and maximum age in the dataset.

# %%
print(f'minimum age is {df.age.min()}')
print(f'maximum age is {df.age.max()}')
# Out:
# minimum age is 20
# maximum age is 85

# %% [markdown]
# Find the shortest and tallest individual in terms of height.

# %%
print(f'minimum height is {df.height.min()}')
print(f'maximum height is {df.height.max()}')
# Out:
# minimum height is 130
# maximum height is 190

# %% [markdown]
# Find the lightest and heaviest individual in terms of weight.

# %%
print(f'lightest individual in term of weight is {df.weight.min()}')
print(f'heaviest individual in term of weight is {df.weight.max()}')
# Out:
# lightest individual in term of weight is 25
# heaviest individual in term of weight is 140

# %% [markdown]
# Find the smallest and largest waistline measurement in the dataset.

# %%
print(f'smallest waistline measurement is {df.waistline.min()}')
print(f'largest waistline measurement is {df.waistline.max()}')
# Out:
# smallest waistline measurement is 8.0
# largest waistline measurement is 999.0

# %% [markdown]
# Calculate the median age, height, weight and waistline measurement of the individuals in the dataset.

# %%
print(f'median of age is {df.age.median()}')
print(f'median of height is {df.height.median()}')
print(f'median of weight is {df.weight.median()}')
print(f'median of waistline measurement is {df.waistline.median()}')
# Out:
# median of age is 45.0
# median of height is 160.0
# median of weight is 60.0
# median of waistline measurement is 81.0

# %% [markdown]
# Calculate the standard deviation of ages, heights, weights and waistline measurements in the dataset.

# %%
print(f"standard deviation age is {df.age.std().round(2)}")
print(f"standard deviation height is {df.height.std().round(2)}")
print(f"standard deviation weight is {df.weight.std().round(2)}")
print(f"standard deviation waistline measurement is {df.waistline.std().round(2)}")
# Out:
# standard deviation age is 14.18
# standard deviation height is 9.28
# standard deviation weight is 12.51
# standard deviation waistline measurement is 11.85

# %% [markdown]
# Find the number of males and females in the dataset.

# %%
print(f'number of male and female is {(df.sex.tolist().count('Male'))} and {(df.sex== 'Female').sum()}')
# Out:
# number of male and female is 526415 and 464931

# %% [markdown]
# Find the most common age, height, weight, waistline measurement in the dataset.

# %%
print(f'most common age is {df.age.mode()[0]}')
print(f'most common height is {df.height.mode()[0]}')
print(f'most common weight is {df.weight.mode()[0]}')
print(f'most common waistline measurement is {df.waistline.mode()[0]}')
# Out:
# most common age is 40
# most common height is 160
# most common weight is 60
# most common waistline measurement is 80.0

# %% [markdown]
# Calculate the correlation between age and height.

# %%
correlation= df.age.corr(df.height)

sns.regplot(x='age', y='height', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %% [markdown]
# Calculate the correlation between age and weight.

# %%
correlation= df.age.corr(df.weight)

sns.regplot(x='age', y='weight', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %% [markdown]
# Calculate the correlation between height and weight

# %%
correlation= df.height.corr(df.weight)

sns.regplot(x='height', y='weight', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %% [markdown]
# Calculate the correlation between age and waistline measurements.

# %%
correlation= df.age.corr(df.waistline)

sns.regplot(x='age', y='waistline', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %% [markdown]
# Calculate the correlation between height and waistline measurements.

# %%
correlation= df.height.corr(df.waistline)

sns.regplot(x='height', y='waistline', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %% [markdown]
# Calculate the correlation between weight and waistline measurements.

# %%
correlation= df.waistline.corr(df.weight)

plt.figure(figsize=(8,6))
sns.regplot(x='waistline', y='weight', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %% [markdown]
# Analyze the distribution of age, height, weight, and waistline measurements using histograms or density plots.

# %%
plt.figure(figsize=(4,5))
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
fig.suptitle('Distribution Analysis', fontsize=16)


sns.histplot(df['age'], kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Age Distribution')

sns.histplot(df['height'], kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Height Distribution')

sns.histplot(df['weight'], kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Weight Distribution')

sns.histplot(df['waistline'], kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Waistline Distribution')

plt.show()

# %% [markdown]
# Find the total number of individuals with a waistline measurement greater than a specific value (e.g.,200 inches).

# %%
dx= df.waistline.copy()
print('the total number of persons with waistline greater than 200 is ',dx[df.waistline>200].count() , ".")
# Out:
# the total number of persons with waistline greater than 200 is  57 .

# %% [markdown]
# Calculate the body mass index (BMI) for each individual using the weight and height.

# %%
df['bmi'] = df['weight'] / ((df['height']/100)**2)
df['bmi']= round(df.bmi, 2)
df.head()
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  hemoglobin  urine_protein  serum_creatinine  \
# 0         1.0  120.0  ...        17.1            1.0               1.0
# 1         1.0  130.0  ...        15.8            1.0               0.9
# 2         1.0  120.0  ...        15.8            1.0               0.9
# 3         1.0  145.0  ...        17.6            1.0               1.1
# 4         1.0  138.0  ...        13.8            1.0               0.8
#
#    SGOT_AST  SGOT_ALT  gamma_GTP  SMK_stat_type_cd  DRK_YN        BMI    bmi
# ...

# %% [markdown]
# Identify outliers in age, height, weight, or waistline measurements using a suitable statistical method

# %%
def detect_outliers(column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

outliers_age = detect_outliers('age')
outliers_height = detect_outliers('height')
outliers_weight = detect_outliers('weight')
outliers_waistline = detect_outliers('waistline')

plt.figure(figsize=(3,6))
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
fig.suptitle('Outlier Analysis', fontsize=16)

sns.boxplot(x='age', data=df, ax=axes[0, 0])
axes[0, 0].scatter(outliers_age.index, outliers_age['age'], color='red', label='Outliers')
axes[0, 0].set_title('Age Outliers')

sns.boxplot(x='height', data=df, ax=axes[0, 1])
axes[0, 1].scatter(outliers_height.index, outliers_height['height'], color='red', label='Outliers')
axes[0, 1].set_title('Height Outliers')

sns.boxplot(x='weight', data=df, ax=axes[1, 0])
axes[1, 0].scatter(outliers_weight.index, outliers_weight['weight'], color='red', label='Outliers')
axes[1, 0].set_title('Weight Outliers')

sns.boxplot(x='waistline', data=df, ax=axes[1, 1])
axes[1, 1].scatter(outliers_waistline.index, outliers_waistline['waistline'], color='red', label='Outliers')
axes[1, 1].set_title('Waistline Outliers')

plt.show()

# %% [markdown]
# ##  importing libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer
from lightgbm import LGBMClassifier
# using pytorch, create a fully connected neural network for binary classification
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import warnings
warnings.filterwarnings('ignore')


plt.rcParams['figure.figsize']=[15,4]

# %% [markdown]
# ##  reading dataset

# %%
# reading csv file
df= pd.read_csv('datasets\\smoking_drinking_dataset_Ver01.csv')
df.head(5)
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %% [markdown]
# ##  Data Preparation & Cleaning

# %% [markdown]
# My dataset is free of null values, and while it does contain some duplicate entries, it is otherwise well-prepared for analysis. The absence of missing values ensures the completeness of the data, while addressing any duplicates will contribute to the accuracy and reliability of subsequent analyses.

# %%
# to get number of rows and columns
df.shape
# Out:
# (991346, 24)

# %%
df.columns
# Out:
# Index(['sex', 'age', 'height', 'weight', 'waistline', 'sight_left',
#        'sight_right', 'hear_left', 'hear_right', 'SBP', 'DBP', 'BLDS',
#        'tot_chole', 'HDL_chole', 'LDL_chole', 'triglyceride', 'hemoglobin',
#        'urine_protein', 'serum_creatinine', 'SGOT_AST', 'SGOT_ALT',
#        'gamma_GTP', 'SMK_stat_type_cd', 'DRK_YN'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991346 entries, 0 to 991345
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sex               991346 non-null  object
#  1   age               991346 non-null  int64
#  2   height            991346 non-null  int64
#  3   weight            991346 non-null  int64
#  4   waistline         991346 non-null  float64
#  5   sight_left        991346 non-null  float64
#  6   sight_right       991346 non-null  float64
#  7   hear_left         991346 non-null  float64
#  8   hear_right        991346 non-null  float64
#  9   SBP               991346 non-null  float64
#  10  DBP               991346 non-null  float64
#  11  BLDS              991346 non-null  float64
#  12  tot_chole         991346 non-null  float64
#  13  HDL_chole         991346 non-null  float64
#  14  LDL_chole         991346 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# 26

# %%
df=df.drop_duplicates()

# %%
df.describe()
# Out:
#                  age         height         weight      waistline  \
# count  991320.000000  991320.000000  991320.000000  991320.000000
# mean       47.614529     162.240563      63.283884      81.233255
# std        14.181346       9.282922      12.514101      11.850296
# min        20.000000     130.000000      25.000000       8.000000
# 25%        35.000000     155.000000      55.000000      74.100000
# 50%        45.000000     160.000000      60.000000      81.000000
# 75%        60.000000     170.000000      70.000000      87.800000
# max        85.000000     190.000000     140.000000     999.000000
#
#           sight_left    sight_right      hear_left     hear_right  \
# count  991320.000000  991320.000000  991320.000000  991320.000000
# mean        0.980833       0.978428       1.031495       1.030476
# std         0.605954       0.604779       0.174652       0.171892
# min         0.100000       0.100000       1.000000       1.000000
# ...

# %%
df['DRK_YN'] = df['DRK_YN'].replace({'Y':1,'N':0})

# %%
df['sex'] = df['sex'].replace({'Male':1,'Female':0})

# %%
def grab_col_names(df, cat_th=10, car_th=20):

    # cat_cols, cat_but_car
    cat_cols = [col for col in df.columns if df[col].dtypes == "O"]
    num_but_cat = [col for col in df.columns if df[col].nunique() < cat_th and
                   df[col].dtypes != "O"]
    cat_but_car = [col for col in df.columns if df[col].nunique() > car_th and
                   df[col].dtypes == "O"]
    cat_cols = cat_cols + num_but_cat
    cat_cols = [col for col in cat_cols if col not in cat_but_car]

    # num_cols
    num_cols = [col for col in df.columns if df[col].dtypes != "O"]
    num_cols = [col for col in num_cols if col not in num_but_cat]

    print(f"Observations(Rows): {df.shape[0]}")
    print(f"Variables(Columns): {df.shape[1]}\n")
    print(f'cat_cols: {len(cat_cols)}\nnum_cols: {len(num_cols)}\ncat_but_car: {len(cat_but_car)}\nnum_but_cat: {len(num_but_cat)}')
    print(f"\ncat_cols: {cat_cols}\nnum_cols: {num_cols}\ncat_but_car: {cat_but_car}\n")

    print(f"\ncat_cols data types:\n\n{df[cat_cols].dtypes}\n\nnum_cols data types:\n\n{df[num_cols].dtypes}\n\ncat_but_car data types:\n\n{df[cat_but_car].dtypes}")

    return cat_cols, num_cols, cat_but_car

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations(Rows): 991320
# Variables(Columns): 24
#
# cat_cols: 6
# num_cols: 18
# cat_but_car: 0
# num_but_cat: 6
#
# cat_cols: ['sex', 'hear_left', 'hear_right', 'urine_protein', 'SMK_stat_type_cd', 'DRK_YN']
# num_cols: ['age', 'height', 'weight', 'waistline', 'sight_left', 'sight_right', 'SBP', 'DBP', 'BLDS', 'tot_chole', 'HDL_chole', 'LDL_chole', 'triglyceride', 'hemoglobin', 'serum_creatinine', 'SGOT_AST', 'SGOT_ALT', 'gamma_GTP']
# cat_but_car: []
#
#
# cat_cols data types:
#
# sex                   int64
# hear_left           float64
# hear_right          float64
# urine_protein       float64
# SMK_stat_type_cd    float64
# DRK_YN                int64
# dtype: object
#
# num_cols data types:
#
# age                   int64
# height                int64
# weight                int64
# waistline           float64
# sight_left          float64
# sight_right         float64
# SBP                 float64
# DBP                 float64
# BLDS                float64
# ...

# %%
smk_stat_mapping = {1: 0, 2: 1, 3: 2}
df['SMK_stat_type_cd'] = df['SMK_stat_type_cd'].map(smk_stat_mapping)

# %%
# outliers detections
def outlier_thresholds(dataframe, col_name, q1=0.05, q3=0.95):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5 * interquantile_range
    low_limit = quartile1 - 1.5 * interquantile_range
    return low_limit, up_limit

def check_outlier(df, col_name):
    low_limit, up_limit = outlier_thresholds(df, col_name)
    if df[(df[col_name] > up_limit) | (df[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False


outlier_cols = []
for col in num_cols:
    if check_outlier(df, col):
        outlier_cols.append(col)
        print(col)
# Out:
# waistline
# sight_left
# sight_right
# SBP
# DBP
# BLDS
# tot_chole
# HDL_chole
# LDL_chole
# triglyceride
# hemoglobin
# serum_creatinine
# SGOT_AST
# SGOT_ALT
# gamma_GTP

# %%
def winsorize(dataframe, col_name, lower_quantile=0.05, upper_quantile=0.95):
    lower_limit, upper_limit = outlier_thresholds(dataframe, col_name, q1=lower_quantile, q3=upper_quantile)
    dataframe[col_name] = dataframe[col_name].apply(lambda x: lower_limit if x < lower_limit else (upper_limit if x > upper_limit else x))


# Defining lower and upper quantiles for Winsorization
lower_quantile = 0.05
upper_quantile = 0.95

for col in outlier_cols:
    winsorize(df, col, lower_quantile, upper_quantile)

# %% [markdown]
# ##  Data Visualization:

# %%
r=4
c=6
it=1
for i in df.columns:
    plt.subplot(r,c,it)
    sns.kdeplot(df[i])
    plt.grid()
    it+=1
plt.tight_layout()
plt.show()

# %%
df.describe()
plt.figure(figsize=(20,20))

sns.heatmap(df.corr(), annot=True)

plt.show(block =True)

# %% [markdown]
# *Observations:* <br>
# *- Both smoking and drinking are negatively correlated with gender. (note males=0, females=1)* <br>
# *- Hemoglobin seems to be also correlated with both smoking and drinking status.* <br>
# *- Smoking and drinking are correlated.* <br>
# *- Triglyceride and gamma GTP levels also show some correlation with smoking.*

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6.5))
plt.subplots_adjust(hspace=0.5)

sns.set(style="whitegrid")

sns.countplot(data=df, x="hear_left", hue="DRK_YN", ax=axes[0, 0])
axes[0, 0].set_xlabel("hear_left")
axes[0, 0].set_ylabel("Count")
axes[0, 0].legend(title="Drinking")

sns.countplot(data=df, x="hear_right", hue="DRK_YN", ax=axes[0, 1])
axes[0, 1].set_xlabel("hear_right")
axes[0, 1].set_ylabel("Count")
axes[0, 1].legend(title="Drinking")

sns.countplot(data=df, x="urine_protein", hue="DRK_YN", ax=axes[1, 0])
axes[1, 0].set_xlabel("urine_protein")
axes[1, 0].set_ylabel("Count")
axes[1, 0].legend(title="Drinking")

sns.countplot(
    data=df, x="SMK_stat_type_cd", hue="DRK_YN", ax=axes[1, 1]
)
axes[1, 1].set_xlabel("SMK_stat_type_cd")
axes[1, 1].set_ylabel("Count")
axes[1, 1].legend(title="Drinking")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observations:
# 1. Participants in the study with abnormal hearing capabilities consume a higher quantity of alcohol. This observation may be attributed to various factors that could potentially influence their drinking habits. One possible explanation could be that individuals experiencing hearing abnormalities may resort to alcohol consumption as a coping mechanism, seeking temporary relief or distraction from their hearing-related challenges. It would be interesting to delve deeper into the underlying motivations and psychological aspects that drive this observed correlation between hearing impairments and increased alcohol consumption.
#
# 2. Individuals categorized with an SMK_stat_type_cd of 1.0, indicating they have never smoked, exhibit a nearly twofold higher likelihood of alcohol consumption. This intriguing finding suggests a significant association between smoking history and alcohol intake. While the exact causal relationship between these variables would require further investigation, it's possible that individuals who have never smoked might have different social or lifestyle factors influencing their alcohol consumption patterns.

# %%
plt.figure(figsize=(5,7))
sns.countplot(data= df, x='sex', hue="DRK_YN")

plt.xticks([0,1],["Male", "Female"])

plt.tight_layout()
plt.show()

# %%
dummy_smoking_df = pd.get_dummies(df, columns=["sex", "DRK_YN"])
correlation_matrix = dummy_smoking_df.corr()

mask = np.triu(correlation_matrix)

plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, cmap="coolwarm", linewidth=0.5, annot=True, fmt=".2f", mask=mask)
plt.show()

# %%
# Count the number of smokers and non-smokers by sex
smoker_males = df[(df['SMK_stat_type_cd'] == 2) & (df['sex'] == 0)]['SMK_stat_type_cd'].count()
smoker_female = df[(df['SMK_stat_type_cd'] == 2) & (df['sex'] == 1)]['SMK_stat_type_cd'].count()
exsmoker_male = df[(df['SMK_stat_type_cd'] == 1) & (df['sex'] == 0)]['SMK_stat_type_cd'].count()
exsmoker_female = df[(df['SMK_stat_type_cd'] == 1) & (df['sex'] == 1)]['SMK_stat_type_cd'].count()
nonsmoker_male = df[(df['SMK_stat_type_cd'] == 0) & (df['sex'] == 0)]['SMK_stat_type_cd'].count()
nonsmoker_female = df[(df['SMK_stat_type_cd'] == 0) & (df['sex'] == 1)]['SMK_stat_type_cd'].count()

# Count the number of drinkers and non-drinkers by sex
female_drinker = df[(df['DRK_YN'] == 0) & (df['sex'] == 1)]['DRK_YN'].count() 
female_nondrinker = df[(df['DRK_YN'] == 1) & (df['sex'] == 1)]['DRK_YN'].count() 
male_drinker = df[(df['DRK_YN'] == 0) & (df['sex'] == 0)]['DRK_YN'].count() 
male_nondrinker = df[(df['DRK_YN'] == 1) & (df['sex'] == 0)]['DRK_YN'].count()

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Sankey( node = dict( pad = 15, thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = ["smoker", "used to smoke", "non-smoker", "male", "female", "drinker", "non-drinker"],
      color = ["#9467bd", "#ff7f0e", "#2ca02c", "#1f77b4", "#d62728", "#8c564b", "#808080"]
    ), link = dict(
      source = [0, 0, 1, 1, 2, 2, 3, 3, 4, 4], 
      target = [3, 4, 3, 4, 3, 4, 5, 6, 5, 6],
      value =  [smoker_males, smoker_female, exsmoker_male, exsmoker_female,
                nonsmoker_male, nonsmoker_female, male_drinker, male_nondrinker,
                female_drinker, female_nondrinker],
      color = ['rgba(148, 103, 189, 0.5)', 'rgba(148, 103, 189, 0.5)', 'rgba(255, 127, 14, 0.5)', 
               'rgba(255, 127, 14, 0.5)', 'rgba(44, 160, 44, 0.5)', 'rgba(44, 160, 44, 0.5)', 
               'rgba(31, 119, 180, 0.5)', 'rgba(31, 119, 180, 0.5)',
               'rgba(214, 39, 40, 0.5)','rgba(214, 39, 40, 0.5)'],
  ))])

fig.update_layout(title_text="Diagram for smokers and drinkers by gender", font_size=10)
fig.show()

# %% [markdown]
# ##  Model Development & Model Performance Evaluation for drinking and smoking

# %% [markdown]
# # Predict drinking status

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score ,classification_report, confusion_matrix
from sklearn import tree

# %%
# create a column with body mass index
df['BMI'] = df['weight'] / ((df['height']/100)**2)

# %% [markdown]
# Prepare data:

# %%
y = df['DRK_YN']
x = df.drop(columns=['DRK_YN'],axis=1)

# create standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# split and scale data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Train a simple decision tree classifier:

# %%
# Decision Tree Classifier
dt = tree.DecisionTreeClassifier()
dt.fit(x_train_scaled,y_train)
y_pred = dt.predict(x_test_scaled)

print("Decision Tree Classifier")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test,y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test,y_pred))
# Out:
# Decision Tree Classifier
# Accuracy: 0.6454777468425937
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.64      0.64     99129
#            1       0.64      0.65      0.65     99135
#
#     accuracy                           0.65    198264
#    macro avg       0.65      0.65      0.65    198264
# weighted avg       0.65      0.65      0.65    198264
#
# Confusion Matrix:
# [[63710 35419]
#  [34870 64265]]

# %% [markdown]
# Tune the parameters of the Decision Tree:

# %%
from sklearn.model_selection import GridSearchCV

# use grid search to find the best parameters for the decision tree classifier
param_grid = {'criterion':['gini','entropy'],'max_depth': np.arange(8, 11)}
dt = tree.DecisionTreeClassifier()
dt_cv = GridSearchCV(dt, param_grid, cv=5)
dt_cv.fit(x_train_scaled,y_train)
print("Tuned Decision Tree Parameters: {}".format(dt_cv.best_params_))
print("Best training score is {}".format(dt_cv.best_score_))

best_dt = dt_cv.best_estimator_
dt_test_score = best_dt.score(x_test_scaled, y_test)
print("Test score of the best decision model: {:.2f}".format(dt_test_score))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 10}
# Best training score is 0.7273710825950239
# Test score of the best decision model: 0.73

# %% [markdown]
# Train a random forest:

# %%
from sklearn.ensemble import RandomForestClassifier

# Define the parameter grids for the models
rf_param_grid = {'n_estimators': [50, 100], 'max_depth': range(7, 9)}

rf = RandomForestClassifier()

rf_cv = GridSearchCV(rf, rf_param_grid, cv=5, verbose=2)
rf_cv.fit(x_train, y_train)
print("Best training score is {}".format(rf_cv.best_score_))

best_rf = rf_cv.best_estimator_

print("Tuned Parameters: {}".format(rf_cv.best_params_))
rf_test_score = best_rf.score(x_test, y_test)
print("Test score of the best random forest model: {:.2f}".format(rf_test_score))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END .......................max_depth=7, n_estimators=50; total time= 1.5min
# [CV] END .......................max_depth=7, n_estimators=50; total time= 1.3min
# [CV] END .......................max_depth=7, n_estimators=50; total time= 1.3min
# [CV] END .......................max_depth=7, n_estimators=50; total time= 1.3min
# [CV] END .......................max_depth=7, n_estimators=50; total time= 1.3min
# [CV] END ......................max_depth=7, n_estimators=100; total time= 1.4min
# [CV] END ......................max_depth=7, n_estimators=100; total time= 2.7min
# [CV] END ......................max_depth=7, n_estimators=100; total time= 1.7min
# [CV] END ......................max_depth=7, n_estimators=100; total time= 1.3min
# [CV] END ......................max_depth=7, n_estimators=100; total time= 1.3min
# [CV] END .......................max_depth=8, n_estimators=50; total time=  44.3s
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

# Define the parameter grids for the model
ada_param_grid = {'n_estimators': [100], 'learning_rate': [1]}

ada = AdaBoostClassifier()

ada_cv = GridSearchCV(ada, ada_param_grid, cv=5, verbose=2)
ada_cv.fit(x_train_scaled, y_train)

print("Tuned Parameters: {}".format(ada_cv.best_params_))

best_ada = ada_cv.best_estimator_

ada_test_score = best_ada.score(x_test_scaled, y_test)
print("Test score of the best AdaBoost model: {:.2f}".format(ada_test_score))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ..................learning_rate=1, n_estimators=100; total time= 2.0min
# [CV] END ..................learning_rate=1, n_estimators=100; total time= 1.8min
# [CV] END ..................learning_rate=1, n_estimators=100; total time= 1.8min
# [CV] END ..................learning_rate=1, n_estimators=100; total time= 1.8min
# [CV] END ..................learning_rate=1, n_estimators=100; total time= 1.9min
# Tuned Parameters: {'learning_rate': 1, 'n_estimators': 100}
# Test score of the best AdaBoost model: 0.73

# %%
from lightgbm import LGBMClassifier

# Define the parameter grids for the model
lgbm_param_grid = {'num_leaves': [50, 70, 90], 'learning_rate': [0.1], 'n_estimators': [200, 300]}

lgbm = LGBMClassifier()

lgbm_cv = GridSearchCV(lgbm, lgbm_param_grid, cv=5, verbose=2)
lgbm_cv.fit(x_train_scaled, y_train)

print("Tuned Parameters: {}".format(lgbm_cv.best_params_))
print("Best training score is {}".format(lgbm_cv.best_score_))

best_lgbm = lgbm_cv.best_estimator_

lgbm_test_score = best_lgbm.score(x_test_scaled, y_test)
print("Test score of the best LGBM model: {:.2f}".format(lgbm_test_score))
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [LightGBM] [Info] Number of positive: 317072, number of negative: 317372
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042297 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2477
# [LightGBM] [Info] Number of data points in the train set: 634444, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499764 -> initscore=-0.000946
# [LightGBM] [Info] Start training from score -0.000946
# [CV] END .learning_rate=0.1, n_estimators=200, num_leaves=50; total time=   9.1s
# [LightGBM] [Info] Number of positive: 317073, number of negative: 317372
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047143 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2478
# ...

# %% [markdown]
# Use neural networks:

# %%
# create a class for the neural network
class Classifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(24, 64)
        self.fc2 = nn.Linear(64, 16)
        self.fc3 = nn.Linear(16, 1)
        self.dropout = nn.Dropout(0.1)
        
    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc3(x))
        return x

# %% [markdown]
# Train function for neural network:

# %%
def train_func(model, train_loader, test_loader, criterion, optimizer, nr_epochs):
    # for each epoch
    for epoch in range(1, nr_epochs+1):
        train_loss = 0
        # set the model to training mode
        model.train()
        # for each batch in the train loader
        for batch_idx, (df, target) in enumerate(train_loader):
            # zero the gradients
            optimizer.zero_grad()
            # get the output of the model
            output = model(df)
            # calculate the loss
            loss = criterion(output, target.unsqueeze(1))
            # backpropagate the loss
            loss.backward()
            # update the weights
            optimizer.step()
            # add loss to batch loss
            train_loss += loss.item()
        # calculate the average loss
        train_loss /= len(train_loader.dataset)
        # print the progress
        if epoch % 1 == 0:
            print('Epoch: {} \tTraining Loss: {:.6f}'.format(
                epoch, train_loss))

        # for each batch in test loader
        test_loss = 0
        correct = 0
        with torch.no_grad():
            for data, target in test_loader:
                # get the output of the model
                output = model(data)
                # calculate the loss
                test_loss += criterion(output, target.unsqueeze(1)).item()
                # get the predicted class
                pred = torch.round(output)
                # calculate the number of correct predictions
                correct += pred.eq(target.unsqueeze(1)).sum().item()
        # calculate the average loss
        test_loss /= len(test_loader.dataset)
        # print the results
        if epoch % 1 == 0:
            print('Test set: Average loss: {:.6f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * correct / len(test_loader.dataset)))

# %% [markdown]
# Prepare data:

# %%
# create a tensor dataset
train_data = TensorDataset(torch.from_numpy(x_train_scaled).float(), torch.from_numpy(y_train.values).float())
test_data = TensorDataset(torch.from_numpy(x_test_scaled).float(), torch.from_numpy(y_test.values).float())

# create data loaders
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %%
# train the model
model = Classifier()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
train_func(model, train_loader, test_loader, criterion, optimizer, nr_epochs=20)
# Out:
# Epoch: 1 	Training Loss: 0.016402
# Test set: Average loss: 0.016339, Accuracy: 145748/198264 (74%)
#
# Epoch: 2 	Training Loss: 0.016228
# Test set: Average loss: 0.016314, Accuracy: 145974/198264 (74%)
#
# Epoch: 3 	Training Loss: 0.016178
# Test set: Average loss: 0.016236, Accuracy: 146094/198264 (74%)
#
# Epoch: 4 	Training Loss: 0.016147
# Test set: Average loss: 0.016248, Accuracy: 145904/198264 (74%)
#
# Epoch: 5 	Training Loss: 0.016133
# Test set: Average loss: 0.016211, Accuracy: 146122/198264 (74%)
#
# Epoch: 6 	Training Loss: 0.016119
# Test set: Average loss: 0.016220, Accuracy: 146182/198264 (74%)
#
# Epoch: 7 	Training Loss: 0.016110
# Test set: Average loss: 0.016209, Accuracy: 146216/198264 (74%)
#
# Epoch: 8 	Training Loss: 0.016101
# Test set: Average loss: 0.016207, Accuracy: 146015/198264 (74%)
#
# Epoch: 9 	Training Loss: 0.016099
# Test set: Average loss: 0.016198, Accuracy: 146040/198264 (74%)
#
# Epoch: 10 	Training Loss: 0.016091
# ...

# %% [markdown]
# # Predict smoking status

# %%
# prepare data
from sklearn.preprocessing import StandardScaler
y = df['SMK_stat_type_cd'] - 1
x = df.drop(columns=['SMK_stat_type_cd'],axis=1)


scaler = StandardScaler()
# split and scale data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Decision Tree

# %%
from sklearn.model_selection import GridSearchCV

# use grid search to find the best parameters for the decision tree classifier
param_grid = {'criterion':['gini','entropy'],'max_depth': np.arange(8, 11)}
dt = tree.DecisionTreeClassifier()
dt_cv = GridSearchCV(dt, param_grid, cv=5)
dt_cv.fit(x_train_scaled,y_train)
print("Tuned Decision Tree Parameters: {}".format(dt_cv.best_params_))
print("Best training score is {}".format(dt_cv.best_score_))

best_dt = dt_cv.best_estimator_
dt_test_score = best_dt.score(x_test_scaled, y_test)
print("Test score of the best decision model: {:.2f}".format(dt_test_score))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 10}
# Best training score is 0.6957541474893512
# Test score of the best decision model: 0.70

# %% [markdown]
# LGBM Classifier

# %%
from lightgbm import LGBMClassifier

# Define the parameter grids for the model
lgbm_param_grid = {'num_leaves': [70, 90], 'learning_rate': [0.1], 'n_estimators': [100, 200]}

lgbm = LGBMClassifier()

lgbm_cv = GridSearchCV(lgbm, lgbm_param_grid, cv=5, verbose=2)
lgbm_cv.fit(x_train_scaled, y_train)

print("Tuned Parameters: {}".format(lgbm_cv.best_params_))
print("Best training score is {}".format(lgbm_cv.best_score_))

best_lgbm = lgbm_cv.best_estimator_

lgbm_test_score = best_lgbm.score(x_test_scaled, y_test)
print("Test score of the best LGBM model: {:.2f}".format(lgbm_test_score))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017105 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2482
# [LightGBM] [Info] Number of data points in the train set: 634444, number of used features: 24
# [LightGBM] [Info] Start training from score -0.497783
# [LightGBM] [Info] Start training from score -1.734518
# [LightGBM] [Info] Start training from score -1.534156
# [CV] END .learning_rate=0.1, n_estimators=100, num_leaves=70; total time=  12.6s
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043124 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2478
# [LightGBM] [Info] Number of data points in the train set: 634445, number of used features: 24
# ...

# %%
# confusion matrix of best model
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay.from_estimator(best_lgbm, x_test_scaled, y_test, display_labels=['Never', 'Former', 'Current'], normalize='true')
plt.title("Smoking status confusion matrix")
# Out:
# Text(0.5, 1.0, 'Smoking status confusion matrix')

# %% [markdown]
# It predicts best the 'never smoked' class.

# %% [markdown]
# Use neural networks:

# %%
# create a class for the neural network
class MulticlassClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(24, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 16)
        self.fc4 = nn.Linear(16, 3)
        self.dropout = nn.Dropout(0.1)
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.fc4(x)
        x = self.softmax(x)
        return x

# %%
def train_func_multiclass(model, train_loader, test_loader, criterion, optimizer, nr_epochs):
    # for each epoch
    for epoch in range(1, nr_epochs+1):
        train_loss = 0
        # set the model to training mode
        model.train()
        # for each batch in the train loader
        for batch_idx, (df, target) in enumerate(train_loader):
            # zero the gradients
            optimizer.zero_grad()
            # get the output of the model
            output = model(df)
            # calculate the loss
            loss = criterion(output, target.long())
            # backpropagate the loss
            loss.backward()
            # update the weights
            optimizer.step()
            # add loss to batch loss
            train_loss += loss.item()
        # calculate the average loss
        train_loss /= len(train_loader.dataset)
        # print the progress
        if epoch % 1 == 0:
            print('Epoch: {} \tTraining Loss: {:.6f}'.format(
                epoch, train_loss))

        # for each batch in test loader
        test_loss = 0
        correct = 0
        with torch.no_grad():
            for df, target in test_loader:
                # get the output of the model
                output = model(df)
                # get the predicted class
                pred = torch.argmax(output, dim=1)
                # calculate the loss
                test_loss += criterion(output, target.long()).item()
                # calculate the number of correct predictions
                correct += pred.eq(target).sum().item()
        # calculate the average loss
        test_loss /= len(test_loader.dataset)
        # print the results
        if epoch % 1 == 0:
            print('Test set: Average loss: {:.6f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
                test_loss, correct, len(test_loader.dataset),
                100. * correct / len(test_loader.dataset)))

# %%
# create a tensor dataset
train_data = TensorDataset(torch.from_numpy(x_train_scaled).float(), torch.from_numpy(y_train.values).float())
test_data = TensorDataset(torch.from_numpy(x_test_scaled).float(), torch.from_numpy(y_test.values).float())

# create data loaders
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %%
# train the model
model = MulticlassClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0015)
train_func_multiclass(model, train_loader, test_loader, criterion, optimizer, nr_epochs=15)
# Out:
# Epoch: 1 	Training Loss: 0.025990
#
# Test set: Average loss: 0.025913, Accuracy: 138512/198270 (70%)
#
#
#
# Epoch: 2 	Training Loss: 0.025891
#
# Test set: Average loss: 0.025840, Accuracy: 139758/198270 (70%)
#
#
#
# Epoch: 3 	Training Loss: 0.025856
#
# Test set: Average loss: 0.025827, Accuracy: 139622/198270 (70%)
#
#
#
# Epoch: 4 	Training Loss: 0.025846
#
# Test set: Average loss: 0.025819, Accuracy: 139754/198270 (70%)
#
#
#
# Epoch: 5 	Training Loss: 0.025837
#
# Test set: Average loss: 0.025831, Accuracy: 139256/198270 (70%)
#
#
#
# Epoch: 6 	Training Loss: 0.025823
#
# Test set: Average loss: 0.025794, Accuracy: 139760/198270 (70%)
#
#
#
# Epoch: 7 	Training Loss: 0.025817
#
# Test set: Average loss: 0.025798, Accuracy: 140014/198270 (71%)
#
#
#
# Epoch: 8 	Training Loss: 0.025812
#
# Test set: Average loss: 0.025804, Accuracy: 139905/198270 (71%)
#
#
#
# Epoch: 9 	Training Loss: 0.025807
#
# Test set: Average loss: 0.025792, Accuracy: 139771/198270 (70%)
#
#
#
# ...

# %%
pred = torch.argmax(model(torch.from_numpy(x_test_scaled).float()), dim=1)
true = torch.from_numpy(y_test.values).float()
ConfusionMatrixDisplay.from_predictions(true, pred, display_labels=['Never', 'Former', 'Current'], normalize='true')
plt.title("Smoking status confusion matrix")
# Out:
# Text(0.5, 1.0, 'Smoking status confusion matrix')

# %% [markdown]
# ## References:

# %%
•	https://www.kaggle.com/datasets/sooyoungher/smoking-drinking-dataset/ . last visitedon:(5 dec 2023). 
•	https://www.udemy.com/course/python-for-machine-learning-data-science-masterclass/. last visitedon:(5 dec 2023)
•	https://www.youtube.com/@statquest. last visitedon:(5 dec 2023)
•	https://lightgbm.readthedocs.io/en/stable/Features.html . last visitedon:(5 dec 2023)
